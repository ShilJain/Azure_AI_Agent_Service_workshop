# %% [markdown]
# ## Agent Recommender
#
# Uses 2 user functions ai_search and reasoning to simulate multi agent interaction. First user function fetches info from AI search and second user function does reasoning to find patterns. The final agent combines output of both the functions to generate the final response.

# %%
from typing import Any

import os
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import (
    AgentEventHandler,
    FunctionTool,
    MessageDeltaChunk,
    RequiredFunctionToolCall,
    RunStep,
    SubmitToolOutputsAction,
    ThreadMessage,
    ThreadRun,
    ToolOutput,
    CodeInterpreterTool,
)
from azure.identity import DefaultAzureCredential
from my_user_functions import user_functions

from dotenv import load_dotenv
load_dotenv()
# Out:
# https://aistudio8056739269.openai.azure.com/openai/deployments/o1-preview/chat/completions?api-version=2024-08-01-preview
# 5e7f673e287f429e89b2179944d046bf
# True

# %% [markdown]
# ### Create AI Project Client

# %%
# Create a project client
project_client = AIProjectClient.from_connection_string(
    credential=DefaultAzureCredential(), conn_str=os.getenv("PROJECT_CONNECTION_STRING")
)
# Out:
# INFO:azure.identity._credentials.environment:No environment configuration found.
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS

# %% [markdown]
# ### Create My EventHandler for tools

# %%
class MyEventHandler(AgentEventHandler):

    def __init__(self, functions: FunctionTool) -> None:
        super().__init__()
        self.functions = functions
        super().__init__()

    def on_message_delta(self, delta: "MessageDeltaChunk") -> None:
        print(f"Text delta received: {delta.text}")

    def on_thread_message(self, message: "ThreadMessage") -> None:
        print(f"ThreadMessage created. ID: {message.id}, Status: {message.status}")

    def on_thread_run(self, run: "ThreadRun") -> None:
        print(f"ThreadRun status: {run.status}")

        if run.status == "failed":
            print(f"Run failed. Error: {run.last_error}")

        if run.status == "requires_action" and isinstance(run.required_action, SubmitToolOutputsAction):
            tool_calls = run.required_action.submit_tool_outputs.tool_calls

            tool_outputs = []
            for tool_call in tool_calls:
                print(f"Tool call: {tool_call}")
                if isinstance(tool_call, RequiredFunctionToolCall):
                    try:
                        output, my_messages = self.functions.execute(tool_call)
                        tool_outputs.append(
                            ToolOutput(
                                tool_call_id=tool_call.id,
                                output=output,
                            )
                        )
                    except Exception as e:
                        print(f"Error executing tool_call {tool_call.id}: {e}")

            print(f"Tool outputs: {tool_outputs}")
            if tool_outputs:
                with project_client.agents.submit_tool_outputs_to_stream(
                    thread_id=run.thread_id, run_id=run.id, tool_outputs=tool_outputs, event_handler=self
                ) as stream:
                    stream.until_done()

    def on_run_step(self, step: "RunStep") -> None:
        print(f"RunStep type: {step.type}, Status: {step.status}")

    def on_error(self, data: str) -> None:
        print(f"An error occurred. Data: {data}")

    def on_done(self) -> None:
        print("Stream completed.")

    def on_unhandled_event(self, event_type: str, event_data: Any) -> None:
        print(f"Unhandled Event Type: {event_type}, Data: {event_data}")

# %% [markdown]
# ### Helper Function to print messages nicely

# %%
def print_messages(messages):
    data = messages.get("data")
    data.reverse()
    for d in data:
        print(d.role)
        print(d.content[0].text.value)

# %%
import logging
# Set the logging level for the Azure SDK
logging.getLogger('azure.core.pipeline.policies.http_logging_policy').setLevel(logging.WARNING)

# %% [markdown]
# ### Define the tools that the agent can use

# %%
from azure.ai.projects.models import FunctionTool,ToolSet
code_interpreter = CodeInterpreterTool()
functions = FunctionTool(functions=user_functions)
#combined_toolset = code_interpreter.definitions + functions.definitions

#combined_toolset
functions.definitions

toolset = ToolSet()
toolset.add(functions)
toolset.definitions
# Out:
# [{'type': 'function', 'function': {'name': 'insights_from_agent', 'description': "Extract the insights from the user's historical electricity consumption data and also future consumption patterns.", 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'No description'}}, 'required': ['query']}}},
#  {'type': 'function', 'function': {'name': 'get_search_results_from_agent', 'description': 'Answer the question related to energy saving suggestions and tips.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The question.'}}, 'required': ['query']}}}]

# %% [markdown]
# ### Create the agent

# %%
prompts = """
You are a helpful assistant designed to make electricity saving tips to customers based on their information and past transaction.
Do not let the customer know the steps you have done.
Here's the steps you must do:
1. You must extract insights from the user's  past and future electricity consumption patterns. You can proceed to step 2 even if you cannot find any insights.
2. You must query the search engine to find energy saving suggestions based on user provided information. 
If the search engine return a list of suggestions, you MUST combine it with the insights extracted from consumption patterns to make the final recommendation.



Always greet the customer.
Do not show any calculations. 
Only use the information from Step 1 and 2 to curate the final response
Do not use emoji.
You leverage code interpreter tool wherever necessary to execute code snippets and provide responses.
"""

# %%
agent = project_client.agents.create_agent(
        model=os.getenv("AZURE_OPENAI_DEPLOYMENT"),
        name="my-assistant",
        description="You take the information from both search agent and insights extractor agent to form final recommendation.",
        instructions=prompts,
        toolset=toolset,
    )

print(f"Created agent, ID: {agent.id}")
# Out:
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.17.1 Python/3.12.9 (Windows-11-10.0.26100-SP0)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://eastus.api.azureml.ms/agents/v1.0/subscriptions/92845077-a16a-4db0-b410-b6305ee39257/resourceGroups/dscertsj/providers/Microsoft.MachineLearningServices/workspaces/shilpajain-agent-demo/assistants?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '1762'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '44f81e6a-e53e-11ef-bd1d-c85ea9ee281f'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.12.9 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Date': 'Fri, 07 Feb 2025 10:28:55 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# Created agent, ID: asst_7tEkJOnJrX4HOkGq3dOVD0K0

# %% [markdown]
# ### Create a  thread

# %%
thread = project_client.agents.create_thread()
print(f"Created thread, thread ID {thread.id}")
# Out:
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://eastus.api.azureml.ms/agents/v1.0/subscriptions/92845077-a16a-4db0-b410-b6305ee39257/resourceGroups/dscertsj/providers/Microsoft.MachineLearningServices/workspaces/shilpajain-agent-demo/threads?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '2'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '65ef72d6-e53e-11ef-9b9d-c85ea9ee281f'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.12.9 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Date': 'Fri, 07 Feb 2025 10:29:24 GMT'
#     'Content-Type': 'application/json'
#     'Content-Length': '137'
#     'Connection': 'keep-alive'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
# Created thread, thread ID thread_FfjzkU14TbUXiFcJciDJThyM

# %% [markdown]
# ## Create Message

# %%
message = project_client.agents.create_message(
        thread_id=thread.id,
        role="user",
        content="Hello, can you help me understand how I consume electricty and also make suggestions on savings.Please note I love cooking ",
    )
print(f"Created message, message ID {message.id}")

with project_client.agents.create_stream(
        thread_id=thread.id, assistant_id=agent.id, event_handler=MyEventHandler(functions)
    ) as stream:
        stream.until_done()
# Out:
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://eastus.api.azureml.ms/agents/v1.0/subscriptions/92845077-a16a-4db0-b410-b6305ee39257/resourceGroups/dscertsj/providers/Microsoft.MachineLearningServices/workspaces/shilpajain-agent-demo/threads/thread_FfjzkU14TbUXiFcJciDJThyM/messages?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '154'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '68299d5f-e53e-11ef-87a3-c85ea9ee281f'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.12.9 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Date': 'Fri, 07 Feb 2025 10:29:27 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://eastus.api.azureml.ms/agents/v1.0/subscriptions/92845077-a16a-4db0-b410-b6305ee39257/resourceGroups/dscertsj/providers/Microsoft.MachineLearningServices/workspaces/shilpajain-agent-demo/threads/thread_FfjzkU14TbUXiFcJciDJThyM/runs?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '65'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '688db740-e53e-11ef-ba0f-c85ea9ee281f'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.12.9 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Created message, message ID msg_hW0vscdkPsHHWhLQcffPGQ3A
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Date': 'Fri, 07 Feb 2025 10:29:29 GMT'
#     'Content-Type': 'text/event-stream; charset=utf-8'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
# ThreadRun status: RunStatus.QUEUED
# ThreadRun status: RunStatus.QUEUED
# ThreadRun status: RunStatus.IN_PROGRESS
# RunStep type: RunStepType.MESSAGE_CREATION, Status: RunStepStatus.IN_PROGRESS
# RunStep type: RunStepType.MESSAGE_CREATION, Status: RunStepStatus.IN_PROGRESS
# ThreadMessage created. ID: msg_9AgXh4ahXnNnNheVrNkaUkO6, Status: MessageStatus.IN_PROGRESS
# ThreadMessage created. ID: msg_9AgXh4ahXnNnNheVrNkaUkO6, Status: MessageStatus.IN_PROGRESS
# Text delta received: Sure
# Text delta received: ,
# Text delta received:  I'd
# Text delta received:  be
# Text delta received:  happy
# Text delta received:  to
# Text delta received:  help
# Text delta received:  you
# Text delta received:  with
# Text delta received:  understanding
# Text delta received:  your
# Text delta received:  electricity
# Text delta received:  consumption
# Text delta received:  and
# Text delta received:  provide
# Text delta received:  you
# Text delta received:  with
# Text delta received:  some
# Text delta received:  energy
# Text delta received: -saving
# Text delta received:  suggestions
# Text delta received: .
# Text delta received:
#
#
# Text delta received: I'll
# Text delta received:  start
# Text delta received:  by
# Text delta received:  analyzing
# Text delta received:  your
# Text delta received:  past
# Text delta received:  and
# Text delta received:  future
# Text delta received:  electricity
# Text delta received:  consumption
# Text delta received:  patterns
# Text delta received: ,
# Text delta received:  and
# Text delta received:  then
# Text delta received:  I'll
# Text delta received:  look
# Text delta received:  up
# Text delta received:  some
# Text delta received:  energy
# Text delta received: -saving
# Text delta received:  tips
# Text delta received:  particularly
# Text delta received:  for
# Text delta received:  someone
# Text delta received:  who
# Text delta received:  loves
# Text delta received:  cooking
# Text delta received: .
# ThreadMessage created. ID: msg_9AgXh4ahXnNnNheVrNkaUkO6, Status: MessageStatus.COMPLETED
# RunStep type: RunStepType.MESSAGE_CREATION, Status: RunStepStatus.COMPLETED
# RunStep type: RunStepType.TOOL_CALLS, Status: RunStepStatus.IN_PROGRESS
# RunStep type: RunStepType.TOOL_CALLS, Status: RunStepStatus.IN_PROGRESS
# c:\Users\shilpajain\AppData\Local\Programs\Python\Python312\Lib\site-packages\nixtla\nixtla_client.py:867: UserWarning: Azure endpoint detected, setting `model` to 'azureai'.
#   warnings.warn("Azure endpoint detected, setting `model` to 'azureai'.")
# INFO:nixtla.nixtla_client:Validating inputs...
# INFO:nixtla.nixtla_client:Preprocessing dataframes...
# INFO:nixtla.nixtla_client:Querying model metadata...
# INFO:nixtla.nixtla_client:Restricting input...
# INFO:nixtla.nixtla_client:Calling Forecast Endpoint...
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-mi223xizmam36.search.windows.net/indexes('vector-2025')/docs/search.post.search?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '348'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': '801c90bd-e53e-11ef-9832-c85ea9ee281f'
#     'User-Agent': 'azsdk-python-search-documents/11.5.2 Python/3.12.9 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; odata.metadata=none; odata.streaming=true; charset=utf-8'
#     'Content-Encoding': 'REDACTED'
#     'Vary': 'REDACTED'
#     'Server': 'Microsoft-IIS/10.0'
#     'Strict-Transport-Security': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'request-id': '801c90bd-e53e-11ef-9832-c85ea9ee281f'
#     'elapsed-time': 'REDACTED'
#     'Date': 'Fri, 07 Feb 2025 10:30:08 GMT'
# INFO:azure.ai.projects.operations._patch:Tool outputs: [{'tool_call_id': 'call_8Fixbdsmj9eyD5IDyvgPKCxh', 'output': "Based on the historical electricity consumption data provided for the year 2024 and the forecasted data for 2025, several insights can be gleaned about your electricity usage patterns.\n\n---\n\n**Historical Consumption Patterns (2024):**\n\n1. **Anomalously Low Consumption in February:**\n   - **February 2024** shows a significantly lower consumption of **101 units**, which is substantially lower than any other month.\n   - This is a stark contrast to adjacent months, such as **January (350 units)** and **March (400 units)**.\n   - **Insight:** The unusually low consumption in February suggests an anomaly. This could be due to factors like absence from the premises, equipment shutdowns, or data recording errors during that month.\n\n2. **Increasing Trend from March to June:**\n   - Consumption increases steadily from **March (400 units)** to **June (597 units)**.\n   - **Insight:** This trend indicates a gradual rise in electricity usage during the spring to early summer months, which could be associated with seasonal factors such as increased cooling needs or extended daylight hours affecting usage patterns.\n\n3. **High Consumption During Mid-Year Months:**\n   - Consumption remains relatively high from **April to September**, ranging between **542 and 597 units**.\n   - **Insight:** Sustained high usage during these months may be linked to consistent operational demands, seasonal activities, or environmental conditions requiring more energy consumption.\n\n4. **Minor Fluctuations in Autumn Months:**\n   - There's a slight decrease in consumption in **October (446 units)** and **November (493 units)** compared to the mid-year peak.\n   - **Insight:** The dip suggests a possible reduction in energy-intensive activities or milder weather reducing the need for heating or cooling.\n\n5. **Peak Consumption in December:**\n   - **December 2024** records the highest consumption at **608 units**.\n   - **Insight:** The spike in December could be attributed to holiday season activities, increased heating requirements, or additional lighting demands during shorter daylight hours.\n\n---\n\n**Forecasted Consumption Patterns (2025):**\n\n1. **Overall Increase in Consumption:**\n   - Forecasted monthly consumption for **2025** ranges from **570 units** to **725 units**, which is consistently higher than the **2024** figures.\n   - **Insight:** The forecast anticipates a significant rise in electricity usage across all months, suggesting changes in operational demands, increased occupancy, or anticipated growth in activities requiring more energy.\n\n2. **Elimination of February Anomaly:**\n   - **February 2025** is forecasted at **570.18 units**, aligning closely with other months.\n   - **Insight:** The normalization of February's consumption indicates that the low usage in **February 2024** was likely an outlier and not indicative of typical patterns.\n\n3. **Peak Consumption Shifts to November:**\n   - The highest forecasted consumption is in **November 2025** at **725.02 units**.\n   - **Insight:** This suggests a shift in peak energy usage to late in the year, possibly due to anticipated events, changes in seasonal usage patterns, or adjustments in operational schedules.\n\n4. **Reduced Variability Across Months:**\n   - Forecasted consumption shows less fluctuation, maintaining relatively high levels throughout the year.\n   - **Insight:** The consistent consumption suggests a stabilization of energy usage patterns, potentially due to standardized operations, uniform occupancy rates, or implemented energy policies leading to steady consumption.\n\n---\n\n**Comparative Insights:**\n\n- **Anomalies and Adjustments:**\n  - The discrepancy between **February 2024** and **February 2025** highlights the significance of anomalies in interpreting consumption data.\n  - **Insight:** Unexpected deviations in one year can infl ...
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://eastus.api.azureml.ms/agents/v1.0/subscriptions/92845077-a16a-4db0-b410-b6305ee39257/resourceGroups/dscertsj/providers/Microsoft.MachineLearningServices/workspaces/shilpajain-agent-demo/threads/thread_FfjzkU14TbUXiFcJciDJThyM/runs/run_3CBXl5Ti59yxE0lG0wCzpRu3/submit_tool_outputs?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '10006'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '80e81a3e-e53e-11ef-a5c8-c85ea9ee281f'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.12.9 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Output length = 2
# • Use a thermal flask to store hot water.
#
# KITCHEN
#
#
#
# Cooking Habits
# • Cover the pot while cooking. Food cooks faster in covered pots.
# • Match the size of the pot with the size of the burner. Energy is lost when small pots are used on larger
#
# burners.
# • Use a microwave oven to cook or warm leftovers instead of a conventional oven.
# • Use an over timer instead of opening the oven door to check your food.
# • Clean your cooking appliances regularly so that heat can be transferred more efficiently.
# • Check the seal on your oven door for cracks or tears to retain heat more effectively.
# • Plan your cooking procedures and prepare your ingredients ahead to reduce unnecessary energy usage.
#
# Washing Machine and Dryer
# • Wash with an optimal laundry load to maximise energy savings.
# • Use the right amount of detergent to avoid washing or rinsing the load unnecessarily.
# • Pre-soak or use a soak cycle for heavily soiled garments to avoid two washing cycles.
# • Use the economy mode to save energy.
# • Select a clothes dryer with energy-saving features, such as the ability to strop drying once it senses that
#
# the clothes are sufficiently dry.
# • Dry with an optimal laundry load whenever possible. Save even more energy by air-drying lightweight
#
# items and using the clothes dryer only for heavier items.
# • Choose a clothes dryer of suitable capacity that meets your family needs.
#
# KITCHEN
#
#
#
# Lighting
# • Choose energy-saving lighting such as compact fluorescent lamps and LED bulbs. Avoid incandescent
#
# lamps.
# • Use dimmers, timers or sensors to control the level and duration of lighting needed.
# • Clean lamps and light fixtures regularly. Dust on lamps and reflectors reduces light transmission.
# • Whenever possible, use natural light for your lighting needs.
#
# Television
# • Dim the light while watching television. This saves electricity while cutting glare from the screen.
# • Always switch off your TV set-top box at the power socket as it consumes the highest standby power.water heater, switch it on before you shower and switch it off immediately
#
# after use.
# • Cut down on long showers. Taking shorter showers save both electricity and water.
#
# Did you know?
# Unlike instantaneous water heaters, storage water heaters continue to use energy to heat water when they are
# left switched on.
#
# BATHROOM
#
#
#
# Refrigerator
# • Cover liquids and food stored in the refrigerator. Uncovered items release moisture, forcing the
#
# compressor to work harder to keep the temperature low.
# • Allow food to cool before putting them into the refrigerator. Hot food causes the compressor to
#
# work harder to keep the temperature low.
# • Do not overload the refrigerator to ensure that cold air can circulate freely.
# • Do not place the refrigerator near heat sources such as stoves, ovens or direct sunlight. The higher
#
# the ambient temperature, the more energy the refrigerator consumes. Instead, place the
# refrigerator in a cool place with good circulation.
#
# • Allow some space around the refrigerator to enable heat to escape from the compressor and
# condensing coil.
#
# • Do not open the refrigerator door unnecessarily.
# • Do not leave the refrigerator door open longer than necessary. Decide what you need from the
#
# refrigerator beforehand.
# • Set the refrigerator to the recommended temperature.
# • Thaw frozen food in the refrigerator instead of using the microwave oven.
# • Ensure that your refrigerator door seals are airtight.
#
# Electric Airport
# • Boil water only when needed.
# • Use a thermal flask to store hot water.
#
# KITCHEN
#
#
#
# Cooking Habits
# • Cover the pot while cooking. Food cooks faster in covered pots.
# • Match the size of the pot with the size of the burner. Energy is lost when small pots are used on larger
#
# burners.
# • Use a microwave oven to cook or warm leftovers instead of a conventional oven.
# • Use an over timer instead of opening the oven door to check your food.
# • Clean your cooking appliances regularly so that heat can be transferred more efficiently.
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Date': 'Fri, 07 Feb 2025 10:30:11 GMT'
#     'Content-Type': 'text/event-stream; charset=utf-8'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
# c:\Users\shilpajain\AppData\Local\Programs\Python\Python312\Lib\site-packages\nixtla\nixtla_client.py:867: UserWarning: Azure endpoint detected, setting `model` to 'azureai'.
#   warnings.warn("Azure endpoint detected, setting `model` to 'azureai'.")
# INFO:nixtla.nixtla_client:Validating inputs...
# INFO:nixtla.nixtla_client:Preprocessing dataframes...
# INFO:nixtla.nixtla_client:Querying model metadata...
# ThreadRun status: RunStatus.REQUIRES_ACTION
# Tool call: {'id': 'call_8Fixbdsmj9eyD5IDyvgPKCxh', 'type': 'function', 'function': {'name': 'insights_from_agent', 'arguments': '{"query": "Extract insights from the user\'s historical and future electricity consumption data"}'}}
# INFO:nixtla.nixtla_client:Restricting input...
# INFO:nixtla.nixtla_client:Calling Forecast Endpoint...
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-mi223xizmam36.search.windows.net/indexes('vector-2025')/docs/search.post.search?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '348'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': '9942f15f-e53e-11ef-aa54-c85ea9ee281f'
#     'User-Agent': 'azsdk-python-search-documents/11.5.2 Python/3.12.9 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# Error executing tool_call call_8Fixbdsmj9eyD5IDyvgPKCxh: too many values to unpack (expected 2)
# Tool call: {'id': 'call_CVs6P4wPfEedOhLhswBCVex0', 'type': 'function', 'function': {'name': 'get_search_results_from_agent', 'arguments': '{"query": "energy saving tips for someone who loves cooking"}'}}
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; odata.metadata=none; odata.streaming=true; charset=utf-8'
#     'Content-Encoding': 'REDACTED'
#     'Vary': 'REDACTED'
#     'Server': 'Microsoft-IIS/10.0'
#     'Strict-Transport-Security': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'request-id': '9942f15f-e53e-11ef-aa54-c85ea9ee281f'
#     'elapsed-time': 'REDACTED'
#     'Date': 'Fri, 07 Feb 2025 10:30:50 GMT'
# Output length = 2
# • Use a thermal flask to store hot water.
#
# KITCHEN
#
#
#
# Cooking Habits
# • Cover the pot while cooking. Food cooks faster in covered pots.
# • Match the size of the pot with the size of the burner. Energy is lost when small pots are used on larger
#
# burners.
# • Use a microwave oven to cook or warm leftovers instead of a conventional oven.
# • Use an over timer instead of opening the oven door to check your food.
# • Clean your cooking appliances regularly so that heat can be transferred more efficiently.
# • Check the seal on your oven door for cracks or tears to retain heat more effectively.
# • Plan your cooking procedures and prepare your ingredients ahead to reduce unnecessary energy usage.
#
# Washing Machine and Dryer
# • Wash with an optimal laundry load to maximise energy savings.
# • Use the right amount of detergent to avoid washing or rinsing the load unnecessarily.
# • Pre-soak or use a soak cycle for heavily soiled garments to avoid two washing cycles.
# • Use the economy mode to save energy.
# • Select a clothes dryer with energy-saving features, such as the ability to strop drying once it senses that
#
# the clothes are sufficiently dry.
# • Dry with an optimal laundry load whenever possible. Save even more energy by air-drying lightweight
#
# items and using the clothes dryer only for heavier items.
# • Choose a clothes dryer of suitable capacity that meets your family needs.
#
# KITCHEN
#
#
#
# Lighting
# • Choose energy-saving lighting such as compact fluorescent lamps and LED bulbs. Avoid incandescent
#
# lamps.
# • Use dimmers, timers or sensors to control the level and duration of lighting needed.
# • Clean lamps and light fixtures regularly. Dust on lamps and reflectors reduces light transmission.
# • Whenever possible, use natural light for your lighting needs.
#
# Television
# • Dim the light while watching television. This saves electricity while cutting glare from the screen.
# • Always switch off your TV set-top box at the power socket as it consumes the highest standby power.water heater, switch it on before you shower and switch it off immediately
#
# after use.
# • Cut down on long showers. Taking shorter showers save both electricity and water.
#
# Did you know?
# Unlike instantaneous water heaters, storage water heaters continue to use energy to heat water when they are
# left switched on.
#
# BATHROOM
#
#
#
# Refrigerator
# • Cover liquids and food stored in the refrigerator. Uncovered items release moisture, forcing the
#
# compressor to work harder to keep the temperature low.
# • Allow food to cool before putting them into the refrigerator. Hot food causes the compressor to
#
# work harder to keep the temperature low.
# • Do not overload the refrigerator to ensure that cold air can circulate freely.
# • Do not place the refrigerator near heat sources such as stoves, ovens or direct sunlight. The higher
#
# the ambient temperature, the more energy the refrigerator consumes. Instead, place the
# refrigerator in a cool place with good circulation.
#
# • Allow some space around the refrigerator to enable heat to escape from the compressor and
# condensing coil.
#
# • Do not open the refrigerator door unnecessarily.
# • Do not leave the refrigerator door open longer than necessary. Decide what you need from the
#
# refrigerator beforehand.
# • Set the refrigerator to the recommended temperature.
# • Thaw frozen food in the refrigerator instead of using the microwave oven.
# • Ensure that your refrigerator door seals are airtight.
#
# Electric Airport
# • Boil water only when needed.
# • Use a thermal flask to store hot water.
#
# KITCHEN
#
#
#
# Cooking Habits
# • Cover the pot while cooking. Food cooks faster in covered pots.
# • Match the size of the pot with the size of the burner. Energy is lost when small pots are used on larger
#
# burners.
# • Use a microwave oven to cook or warm leftovers instead of a conventional oven.
# • Use an over timer instead of opening the oven door to check your food.
# • Clean your cooking appliances regularly so that heat can be transferred more efficiently.
# Error executing tool_call call_CVs6P4wPfEedOhLhswBCVex0: too many values to unpack (expected 2)
# Tool outputs: []
# Stream completed.
# RunStep type: RunStepType.TOOL_CALLS, Status: RunStepStatus.COMPLETED
# ThreadRun status: RunStatus.QUEUED
# ThreadRun status: RunStatus.IN_PROGRESS
# RunStep type: RunStepType.MESSAGE_CREATION, Status: RunStepStatus.IN_PROGRESS
# RunStep type: RunStepType.MESSAGE_CREATION, Status: RunStepStatus.IN_PROGRESS
# ThreadMessage created. ID: msg_CZ6CKicsfo9rySsTHR8PXGRw, Status: MessageStatus.IN_PROGRESS
# ThreadMessage created. ID: msg_CZ6CKicsfo9rySsTHR8PXGRw, Status: MessageStatus.IN_PROGRESS
# Text delta received: Hello
# Text delta received: !
# Text delta received:  Based
# Text delta received:  on
# Text delta received:  the
# Text delta received:  analysis
# Text delta received:  of
# Text delta received:  your
# Text delta received:  past
# Text delta received:  and
# Text delta received:  forecast
# Text delta received: ed
# Text delta received:  electricity
# Text delta received:  consumption
# Text delta received:  patterns
# Text delta received: ,
# Text delta received:  as
# Text delta received:  well
# Text delta received:  as
# Text delta received:  some
# Text delta received:  specific
# Text delta received:  energy
# Text delta received: -saving
# Text delta received:  tips
# Text delta received:  for
# Text delta received:  someone
# Text delta received:  who
# Text delta received:  loves
# Text delta received:  cooking
# Text delta received: ,
# Text delta received:  I
# Text delta received:  have
# Text delta received:  some
# Text delta received:  insights
# Text delta received:  and
# Text delta received:  suggestions
# Text delta received:  for
# Text delta received:  you
# Text delta received: .
#
#
# Text delta received: ###
# Text delta received:  Insights
# Text delta received:  from
# Text delta received:  Your
# Text delta received:  Electricity
# Text delta received:  Consumption
# Text delta received:  Patterns
# Text delta received: :
#
#
# Text delta received: **
# Text delta received: 202
# Text delta received: 4
# Text delta received:  Historical
# Text delta received:  Patterns
# Text delta received: :
# Text delta received: **
#
# Text delta received: 1
# Text delta received: .
# Text delta received:  **
# Text delta received: An
# Text delta received: omal
# Text delta received: ously
# Text delta received:  Low
# Text delta received:  Consumption
# Text delta received:  in
# Text delta received:  February
# Text delta received: :**
# Text delta received:  February
# Text delta received:
# Text delta received: 202
# Text delta received: 4
# Text delta received:  shows
# Text delta received:  significantly
# Text delta received:  lower
# Text delta received:  consumption
# Text delta received:  compared
# Text delta received:  to
# Text delta received:  other
# Text delta received:  months
# Text delta received: .
#
# Text delta received: 2
# Text delta received: .
# Text delta received:  **
# Text delta received: Increasing
# Text delta received:  Trend
# Text delta received:  from
# Text delta received:  March
# Text delta received:  to
# Text delta received:  June
# Text delta received: :**
# Text delta received:  Consumption
# Text delta received:  rises
# Text delta received:  steadily
# Text delta received:  during
# Text delta received:  these
# Text delta received:  months
# Text delta received: ,
# Text delta received:  likely
# Text delta received:  due
# Text delta received:  to
# Text delta received:  seasonal
# Text delta received:  changes
# Text delta received: .
#
# Text delta received: 3
# Text delta received: .
# Text delta received:  **
# Text delta received: High
# Text delta received:  Consumption
# Text delta received:  in
# Text delta received:  Mid
# Text delta received: -Year
# Text delta received:  Months
# Text delta received: :**
# Text delta received:  From
# Text delta received:  April
# Text delta received:  to
# Text delta received:  September
# Text delta received: ,
# Text delta received:  your
# Text delta received:  electricity
# Text delta received:  usage
# Text delta received:  remained
# Text delta received:  relatively
# Text delta received:  high
# Text delta received: .
#
# Text delta received: 4
# Text delta received: .
# Text delta received:  **
# Text delta received: Minor
# Text delta received:  Fl
# Text delta received: uct
# Text delta received: u
# Text delta received: ations
# Text delta received:  in
# Text delta received:  Autumn
# Text delta received:  Months
# Text delta received: :**
# Text delta received:  There's
# Text delta received:  a
# Text delta received:  slight
# Text delta received:  decrease
# Text delta received:  in
# Text delta received:  October
# Text delta received:  and
# Text delta received:  November
# Text delta received: .
#
# Text delta received: 5
# Text delta received: .
# Text delta received:  **
# Text delta received: Peak
# Text delta received:  Consumption
# Text delta received:  in
# Text delta received:  December
# Text delta received: :**
# Text delta received:  December
# Text delta received:  recorded
# Text delta received:  the
# Text delta received:  highest
# Text delta received:  consumption
# Text delta received: ,
# Text delta received:  possibly
# Text delta received:  due
# Text delta received:  to
# Text delta received:  holiday
# Text delta received:  season
# Text delta received:  activities
# Text delta received: .
#
#
# Text delta received: **
# Text delta received: 202
# Text delta received: 5
# Text delta received:  Forecast
# Text delta received: ed
# Text delta received:  Patterns
# Text delta received: :
# Text delta received: **
#
# Text delta received: 1
# Text delta received: .
# Text delta received:  **
# Text delta received: Overall
# Text delta received:  Increase
# Text delta received:  in
# Text delta received:  Consumption
# Text delta received: :**
# Text delta received:  Expected
# Text delta received:  higher
# Text delta received:  monthly
# Text delta received:  consumption
# Text delta received:  across
# Text delta received:  the
# Text delta received:  year
# Text delta received: .
#
# Text delta received: 2
# Text delta received: .
# Text delta received:  **
# Text delta received: Normalized
# Text delta received:  February
# Text delta received:  Consumption
# Text delta received: :**
# Text delta received:  February
# Text delta received:
# Text delta received: 202
# Text delta received: 5
# Text delta received: 's
# Text delta received:  forecast
# Text delta received:  aligns
# Text delta received:  with
# Text delta received:  other
# Text delta received:  months
# Text delta received: .
#
# Text delta received: 3
# Text delta received: .
# Text delta received:  **
# Text delta received: Peak
# Text delta received:  Consumption
# Text delta received:  Sh
# Text delta received: ifts
# Text delta received:  to
# Text delta received:  November
# Text delta received: :**
# Text delta received:  The
# Text delta received:  highest
# Text delta received:  anticipated
# Text delta received:  consumption
# Text delta received:  in
# Text delta received:  November
# Text delta received: .
#
# Text delta received: 4
# Text delta received: .
# Text delta received:  **
# Text delta received: Reduced
# Text delta received:  Vari
# Text delta received: ability
# Text delta received:  Across
# Text delta received:  Months
# Text delta received: :**
# Text delta received:  Cons
# Text delta received: ist
# Text delta received: ently
# Text delta received:  high
# Text delta received:  consumption
# Text delta received:  levels
# Text delta received:  throughout
# Text delta received:  the
# Text delta received:  year
# Text delta received: .
#
#
# Text delta received: ###
# Text delta received:  Energy
# Text delta received: -S
# Text delta received: aving
# Text delta received:  Tips
# Text delta received:  Specialized
# Text delta received:  for
# Text delta received:  Cooking
# Text delta received:  Enth
# Text delta received: usi
# Text delta received: asts
# Text delta received: :
#
#
# Text delta received: **
# Text delta received: Cooking
# Text delta received:  Hab
# Text delta received: its
# Text delta received: :
# Text delta received: **
#
# Text delta received: 1
# Text delta received: .
# Text delta received:  **
# Text delta received: Cover
# Text delta received:  the
# Text delta received:  Pot
# Text delta received: :**
# Text delta received:  Food
# Text delta received:  cooks
# Text delta received:  faster
# Text delta received:  in
# Text delta received:  covered
# Text delta received:  pots
# Text delta received: ,
# Text delta received:  saving
# Text delta received:  energy
# Text delta received: .
#
# Text delta received: 2
# Text delta received: .
# Text delta received:  **
# Text delta received: Match
# Text delta received:  Pot
# Text delta received:  and
# Text delta received:  Burner
# Text delta received:  Sizes
# Text delta received: :**
# Text delta received:  Use
# Text delta received:  pots
# Text delta received:  that
# Text delta received:  match
# Text delta received:  the
# Text delta received:  size
# Text delta received:  of
# Text delta received:  the
# Text delta received:  burner
# Text delta received:  to
# Text delta received:  avoid
# Text delta received:  energy
# Text delta received:  loss
# Text delta received: .
#
# Text delta received: 3
# Text delta received: .
# Text delta received:  **
# Text delta received: Use
# Text delta received:  Microwave
# Text delta received: :**
# Text delta received:  Cook
# Text delta received:  or
# Text delta received:  warm
# Text delta received:  leftovers
# Text delta received:  in
# Text delta received:  a
# Text delta received:  microwave
# Text delta received:  instead
# Text delta received:  of
# Text delta received:  a
# Text delta received:  conventional
# Text delta received:  oven
# Text delta received: .
#
# Text delta received: 4
# Text delta received: .
# Text delta received:  **
# Text delta received: Util
# Text delta received: ize
# Text delta received:  Oven
# Text delta received:  Timer
# Text delta received: :**
# Text delta received:  Use
# Text delta received:  a
# Text delta received:  timer
# Text delta received:  instead
# Text delta received:  of
# Text delta received:  opening
# Text delta received:  the
# Text delta received:  oven
# Text delta received:  door
# Text delta received:  to
# Text delta received:  check
# Text delta received:  food
# Text delta received: .
#
# Text delta received: 5
# Text delta received: .
# Text delta received:  **
# Text delta received: Regular
# Text delta received:  Cleaning
# Text delta received: :**
# Text delta received:  Clean
# Text delta received:  your
# Text delta received:  cooking
# Text delta received:  appliances
# Text delta received:  regularly
# Text delta received:  to
# Text delta received:  improve
# Text delta received:  efficiency
# Text delta received: .
#
# Text delta received: 6
# Text delta received: .
# Text delta received:  **
# Text delta received: Check
# Text delta received:  Oven
# Text delta received:  Seal
# Text delta received: :**
# Text delta received:  Ensure
# Text delta received:  the
# Text delta received:  oven
# Text delta received:  door
# Text delta received:  seal
# Text delta received:  is
# Text delta received:  intact
# Text delta received:  for
# Text delta received:  better
# Text delta received:  heat
# Text delta received:  retention
# Text delta received: .
#
# Text delta received: 7
# Text delta received: .
# Text delta received:  **
# Text delta received: Plan
# Text delta received:  Cooking
# Text delta received: :**
# Text delta received:  Prepare
# Text delta received:  ingredients
# Text delta received:  ahead
# Text delta received:  to
# Text delta received:  reduce
# Text delta received:  unnecessary
# Text delta received:  energy
# Text delta received:  usage
# Text delta received: .
#
#
# Text delta received: **
# Text delta received: Re
# Text delta received: friger
# Text delta received: ator
# Text delta received:  Management
# Text delta received: :
# Text delta received: **
#
# Text delta received: 1
# Text delta received: .
# Text delta received:  **
# Text delta received: Cover
# Text delta received:  Stored
# Text delta received:  Items
# Text delta received: :**
# Text delta received:  Covered
# Text delta received:  items
# Text delta received:  release
# Text delta received:  less
# Text delta received:  moisture
# Text delta received: ,
# Text delta received:  making
# Text delta received:  the
# Text delta received:  compressor
# Text delta received:  work
# Text delta received:  less
# Text delta received:  hard
# Text delta received: .
#
# Text delta received: 2
# Text delta received: .
# Text delta received:  **
# Text delta received: Cool
# Text delta received:  Food
# Text delta received:  Before
# Text delta received:  St
# Text delta received: oring
# Text delta received: :**
# Text delta received:  Let
# Text delta received:  food
# Text delta received:  cool
# Text delta received:  before
# Text delta received:  placing
# Text delta received:  it
# Text delta received:  in
# Text delta received:  the
# Text delta received:  refrigerator
# Text delta received: .
#
# Text delta received: 3
# Text delta received: .
# Text delta received:  **
# Text delta received: Avoid
# Text delta received:  Over
# Text delta received: loading
# Text delta received: :**
# Text delta received:  Ensure
# Text delta received:  cold
# Text delta received:  air
# Text delta received:  can
# Text delta received:  circulate
# Text delta received:  freely
# Text delta received:  by
# Text delta received:  not
# Text delta received:  over
# Text delta received: loading
# Text delta received: .
#
# Text delta received: 4
# Text delta received: .
# Text delta received:  **
# Text delta received: Proper
# Text delta received:  Placement
# Text delta received: :**
# Text delta received:  Keep
# Text delta received:  the
# Text delta received:  refrigerator
# Text delta received:  away
# Text delta received:  from
# Text delta received:  heat
# Text delta received:  sources
# Text delta received:  like
# Text delta received:  st
# Text delta received: oves
# Text delta received: .
#
# Text delta received: 5
# Text delta received: .
# Text delta received:  **
# Text delta received: Eff
# Text delta received: icient
# Text delta received:  Use
# Text delta received: :**
# Text delta received:  Don
# Text delta received: ’t
# Text delta received:  open
# Text delta received:  the
# Text delta received:  door
# Text delta received:  unnecessarily
# Text delta received: ,
# Text delta received:  and
# Text delta received:  keep
# Text delta received:  it
# Text delta received:  open
# Text delta received:  only
# Text delta received:  as
# Text delta received:  long
# Text delta received:  as
# Text delta received:  needed
# Text delta received: .
#
# Text delta received: 6
# Text delta received: .
# Text delta received:  **
# Text delta received: Recommended
# Text delta received:  Temperature
# Text delta received: :**
# Text delta received:  Set
# Text delta received:  the
# Text delta received:  refrigerator
# Text delta received:  to
# Text delta received:  the
# Text delta received:  optimal
# Text delta received:  temperature
# Text delta received: .
#
# Text delta received: 7
# Text delta received: .
# Text delta received:  **
# Text delta received: Door
# Text delta received:  Se
# Text delta received: als
# Text delta received: :**
# Text delta received:  Ensure
# Text delta received:  seals
# Text delta received:  are
# Text delta received:  airtight
# Text delta received:  to
# Text delta received:  maintain
# Text delta received:  efficiency
# Text delta received: .
#
#
# Text delta received: By
# Text delta received:  understanding
# Text delta received:  your
# Text delta received:  consumption
# Text delta received:  patterns
# Text delta received:  and
# Text delta received:  incorporating
# Text delta received:  these
# Text delta received:  energy
# Text delta received: -saving
# Text delta received:  tips
# Text delta received: ,
# Text delta received:  particularly
# Text delta received:  in
# Text delta received:  your
# Text delta received:  kitchen
# Text delta received: ,
# Text delta received:  you
# Text delta received:  can
# Text delta received:  manage
# Text delta received:  your
# Text delta received:  electricity
# Text delta received:  usage
# Text delta received:  more
# Text delta received:  effectively
# Text delta received:  and
# Text delta received:  reduce
# Text delta received:  your
# Text delta received:  overall
# Text delta received:  energy
# Text delta received:  consumption
# Text delta received: .
# Text delta received:  If
# Text delta received:  you
# Text delta received:  need
# Text delta received:  more
# Text delta received:  specific
# Text delta received:  advice
# Text delta received:  or
# Text delta received:  have
# Text delta received:  any
# Text delta received:  other
# Text delta received:  questions
# Text delta received: ,
# Text delta received:  feel
# Text delta received:  free
# Text delta received:  to
# Text delta received:  ask
# Text delta received: !
# ThreadMessage created. ID: msg_CZ6CKicsfo9rySsTHR8PXGRw, Status: MessageStatus.COMPLETED
# RunStep type: RunStepType.MESSAGE_CREATION, Status: RunStepStatus.COMPLETED
# ThreadRun status: RunStatus.COMPLETED
# Stream completed.

# %%
print_messages(project_client.agents.list_messages(thread_id=thread.id))
# Out:
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://eastus.api.azureml.ms/agents/v1.0/subscriptions/92845077-a16a-4db0-b410-b6305ee39257/resourceGroups/dscertsj/providers/Microsoft.MachineLearningServices/workspaces/shilpajain-agent-demo/threads/thread_FfjzkU14TbUXiFcJciDJThyM/messages?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'c70d0b60-e53e-11ef-8d32-c85ea9ee281f'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.12.9 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Date': 'Fri, 07 Feb 2025 10:32:07 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# MessageRole.USER
# Hello, can you help me understand how I consume electricty and also make suggestions on savings.Please note I love cooking
# MessageRole.AGENT
# Sure, I'd be happy to help you with understanding your electricity consumption and provide you with some energy-saving suggestions.
#
# I'll start by analyzing your past and future electricity consumption patterns, and then I'll look up some energy-saving tips particularly for someone who loves cooking.
# MessageRole.AGENT
# Hello! Based on the analysis of your past and forecasted electricity consumption patterns, as well as some specific energy-saving tips for someone who loves cooking, I have some insights and suggestions for you.
#
# ### Insights from Your Electricity Consumption Patterns:
#
# **2024 Historical Patterns:**
# 1. **Anomalously Low Consumption in February:** February 2024 shows significantly lower consumption compared to other months.
# 2. **Increasing Trend from March to June:** Consumption rises steadily during these months, likely due to seasonal changes.
# 3. **High Consumption in Mid-Year Months:** From April to September, your electricity usage remained relatively high.
# 4. **Minor Fluctuations in Autumn Months:** There's a slight decrease in October and November.
# 5. **Peak Consumption in December:** December recorded the highest consumption, possibly due to holiday season activities.
#
# **2025 Forecasted Patterns:**
# 1. **Overall Increase in Consumption:** Expected higher monthly consumption across the year.
# 2. **Normalized February Consumption:** February 2025's forecast aligns with other months.
# 3. **Peak Consumption Shifts to November:** The highest anticipated consumption in November.
# 4. **Reduced Variability Across Months:** Consistently high consumption levels throughout the year.
#
# ### Energy-Saving Tips Specialized for Cooking Enthusiasts:
#
# **Cooking Habits:**
# 1. **Cover the Pot:** Food cooks faster in covered pots, saving energy.
# 2. **Match Pot and Burner Sizes:** Use pots that match the size of the burner to avoid energy loss.
# 3. **Use Microwave:** Cook or warm leftovers in a microwave instead of a conventional oven.
# 4. **Utilize Oven Timer:** Use a timer instead of opening the oven door to check food.
# 5. **Regular Cleaning:** Clean your cooking appliances regularly to improve efficiency.
# 6. **Check Oven Seal:** Ensure the oven door seal is intact for better heat retention.
# 7. **Plan Cooking:** Prepare ingredients ahead to reduce unnecessary energy usage.
#
# **Refrigerator Management:**
# 1. **Cover Stored Items:** Covered items release less moisture, making the compressor work less hard.
# 2. **Cool Food Before Storing:** Let food cool before placing it in the refrigerator.
# 3. **Avoid Overloading:** Ensure cold air can circulate freely by not overloading.
# 4. **Proper Placement:** Keep the refrigerator away from heat sources like stoves.
# 5. **Efficient Use:** Don’t open the door unnecessarily, and keep it open only as long as needed.
# 6. **Recommended Temperature:** Set the refrigerator to the optimal temperature.
# 7. **Door Seals:** Ensure seals are airtight to maintain efficiency.
#
# By understanding your consumption patterns and incorporating these energy-saving tips, particularly in your kitchen, you can manage your electricity usage more effectively and reduce your overall energy consumption. If you need more specific advice or have any other questions, feel free to ask!
